# %% [markdown]
# Trio Saputro | 5220411097
#
# Deskripsi Soal Mini Projek
# 1. Setiap mahasiswa hanya diperbolehkan melakukan submit 1 kali pada repository GitHub masing-masing.
# 2. Ketika ada pengambilan CPMK, silakan upload tugas ke repository GitHub pribadi sesuai CPMK yang diminta.
# 3. Dosen akan melakukan pengecekan pada setiap repository untuk menilai CPMK 2, 4, 5 dan 6
#
# Jawab!!!
# Pada tugas kali ini saya melakukan scraping data/ crawling data menggunakan tweet harvest. Saya mengambil tema Analisis sentimen terhadap ulasan data twitter / X terkait isu gempa megathrust. Isu megathrust akhir akhir ini kembali trending kembali setelah beberapa tahun yang lalu setelah pernyataan BMKG terkait potensi gempa megathrust di laut selatan samudra hindia. Berikut adalah langkah-langkah yang saya ambil dalam mengerjakan tugas mini projek ini.

# %% [markdown]
# ## 1. Crawl data auth token X
# Scraping atai Crawling data ini menggunakan auth token dari aplikasi x itu sendiri. Ini bisa dilakukan dengan cara login akun X terlebih dahulu lalu klik kanan pada tampilan beranda dan pilih menu inspect, pada menu inspect tersebut tinggal memilik cookies dan mencari kode yang ada pada tampilan auth token.

# %%
# Auth Token
twitter_auth_token = '....................'

# %%
# # Import required Python package
# !pip install pandas

# # Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %% [markdown]
# ## ## 2. Crawling data X
#  auth token didapatkan, langkah selanjutnya adalah melakukan scraping itu sendiri. karena pengambilan data menggunakan tweet harvest dibatasi, disini saya melakukan crawling secara bertahap yaitu 4 tahap agar mendaoatkan data lebih dari 1000 sesuai deskripsi soal.

# %% [markdown]
# ## Crawl tahap 1

# %%
# # Crawl Data

# filename = 'megathrust1.csv'
# search_keyword = 'megathrust since:2022-01-01 until:2023-01-01 lang:id'
# # search_keyword = 'megathrust since:2023-01-01 until:2024-01-01 lang:id'
# # search_keyword = 'megathrust since:2024-01-01 until:2025-01-01 lang:id'
# limit = 1000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}

# %%
# import pandas as pd

# # Specify the path to your CSV file
# file_path = f"tweets-data/{filename}"

# # Read the CSV file into a pandas DataFrame
# df = pd.read_csv(file_path, delimiter=",")

# # Display the DataFrame
# display(df)

# %%
# # Cek jumlah data yang didapatkan

# num_tweets = len(df)
# print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")

# %% [markdown]
# ## Crawl tahap 2

# %%
# Crawl Data

filename = 'megathrust2.csv'
# search_keyword = 'megathrust since:2022-01-01 until:2023-01-01 lang:id'
search_keyword = 'megathrust since:2023-01-01 until:2024-01-01 lang:id'
# search_keyword = 'megathrust since:2024-01-01 until:2025-01-01 lang:id'
limit = 1000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2)
# Filling in keywords: megathrust since:2023-01-01 until:2024-01-01 lang:id
#
#  (3) (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/megathrust2.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/megathrust2.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/megathrust2.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/megathrust2.csv
# Total tweets saved: 80
#
# -- Scrolling... (1)
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1733381944103289080  Sat Dec 09 14:16:13 +0000 2023               5
# 1    1733381944103289080  Sat Dec 09 14:14:54 +0000 2023               0
# 2    1733381944103289080  Sat Dec 09 12:16:05 +0000 2023              12
# 3    1733344846591435107  Sat Dec 09 10:33:31 +0000 2023               0
# 4    1733381944103289080  Sat Dec 09 07:03:54 +0000 2023             755
# ..                   ...                             ...             ...
# 254  1611964124329836546  Sun Jan 08 12:32:43 +0000 2023               0
# 255  1611496119728734208  Fri Jan 06 22:53:09 +0000 2023               0
# 256  1611494518125400065  Fri Jan 06 22:46:47 +0000 2023               3
# 257  1610779636576964609  Thu Jan 05 01:20:18 +0000 2023               1
# 258  1609860214580465665  Mon Jan 02 10:32:39 +0000 2023               1
#
#                                              full_text               id_str  \
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 259.

# %% [markdown]
# ## Crawl tahap 3

# %%
# Crawl Data

filename = 'megathrust3.csv'
# search_keyword = 'megathrust since:2022-01-01 until:2023-01-01 lang:id'
# search_keyword = 'megathrust since:2023-01-01 until:2024-01-01 lang:id'
search_keyword = 'megathrust since:2024-01-01 until:2025-01-01 lang:id'
limit = 1000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: megathrust since:2024-01-01 until:2025-01-01 lang:id
#
#  (4)
#
# Your tweets saved to: /content/tweets-data/megathrust3.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/megathrust3.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/megathrust3.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/megathrust3.csv
# Total tweets saved: 80
#
# -- Scrolling... (1) (2)
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1874235370369642672  Tue Dec 31 23:25:08 +0000 2024               0
# 1    1874155073171054805  Tue Dec 31 18:15:26 +0000 2024               0
# 2    1874138622389350632  Tue Dec 31 17:00:42 +0000 2024               2
# 3    1874045632685703527  Tue Dec 31 16:31:17 +0000 2024               0
# 4    1874032346833575964  Tue Dec 31 09:58:23 +0000 2024               0
# ..                   ...                             ...             ...
# 267  1848588233573339272  Tue Oct 22 04:52:34 +0000 2024               0
# 268  1848013762026188923  Tue Oct 22 04:09:58 +0000 2024               0
# 269  1848310558250209301  Tue Oct 22 01:48:40 +0000 2024               0
# 270  1848513127081763069  Mon Oct 21 23:54:07 +0000 2024               0
# 271  1848411984594952270  Mon Oct 21 17:12:13 +0000 2024               1
#
#                                              full_text               id_str  \
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 272.

# %% [markdown]
# ## Crawl tahap 4

# %%
# Crawl Data

filename = 'megathrust4.csv'
# search_keyword = 'megathrust since:2022-01-01 until:2023-01-01 lang:id'
# search_keyword = 'megathrust since:2023-01-01 until:2024-01-01 lang:id'
# search_keyword = 'megathrust since:2024-01-01 until:2025-01-01 lang:id'
search_keyword = 'megathrust since:2025-01-01 until:2025-10-01 lang:id'
limit = 1000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2)
# Filling in keywords: megathrust since:2025-01-01 until:2025-10-01 lang:id
#
#  (3)
#
# Your tweets saved to: /content/tweets-data/megathrust4.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/megathrust4.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/megathrust4.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/megathrust4.csv
# Total tweets saved: 80
#
# -- Scrolling... (1) (2) (3)
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1973012879034245197  Tue Sep 30 22:43:16 +0000 2025               0
# 1    1973146229862535470  Tue Sep 30 22:01:35 +0000 2025               0
# 2    1973089451321491743  Tue Sep 30 18:35:30 +0000 2025               1
# 3    1973090741342630046  Tue Sep 30 18:21:05 +0000 2025               4
# 4    1973075078272204989  Tue Sep 30 17:18:51 +0000 2025               0
# ..                   ...                             ...             ...
# 709  1902906535241494789  Fri Mar 21 02:14:06 +0000 2025             235
# 710  1902579651517538305  Fri Mar 21 01:55:48 +0000 2025               0
# 711  1902734835833307350  Thu Mar 20 20:14:53 +0000 2025               1
# 712  1902677757672489304  Thu Mar 20 18:29:27 +0000 2025               0
# 713  1902787886501728512  Thu Mar 20 18:22:38 +0000 2025               0
#
#                                              full_text               id_str  \
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 714.
